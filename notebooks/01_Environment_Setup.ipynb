# %% [markdown]
# <a href="https://colab.research.google.com/github/Musharrafmrm/hybrid-ecommerce-issue-detection/blob/main/notebooks/01_Environment_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =============================================================================
# 01_Environment_Setup.ipynb
# Hybrid Machine Learning for E-Commerce Review Issue Detection
# Student: M.R.M. Musharraf (20APC5036)
# =============================================================================

# %%
print("🚀 Starting Environment Setup...\n")
# Out:
# 🚀 Starting Environment Setup...

# %%
# Cell 1: Install all libraries
# !pip install -q pandas numpy nltk spacy gensim scikit-learn transformers torch torchvision torchaudio
# !pip install -q beautifulsoup4 scrapy selenium lxml tqdm

print("✅ All libraries installed!")
# Out:
# ✅ All libraries installed!

# %%
# Cell 2: Download NLTK data
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

print("✅ NLTK data downloaded!")
# Out:
# ✅ NLTK data downloaded!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Cell 3: Download spaCy English model
# !python -m spacy download en_core_web_sm

print("✅ spaCy model downloaded!")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 74.4 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# ✅ spaCy model downloaded!

# %%
# Cell 4: Test all imports
import pandas as pd
import numpy as np
import nltk
import spacy
import gensim
from sklearn.feature_extraction.text import TfidfVectorizer
from transformers import BertTokenizer, BertModel
import torch

print("✅ All libraries imported successfully!")
print(f"PyTorch version: {torch.__version__}")
print(f"GPU Available: {torch.cuda.is_available()}")
# Out:
# ✅ All libraries imported successfully!
# PyTorch version: 2.10.0+cu128
# GPU Available: True

# %%
# Cell 5: Final confirmation
print("="*70)
print("🎉 ENVIRONMENT SETUP COMPLETED SUCCESSFULLY!")
print("="*70)
# Out:
# ...
# 🎉 ENVIRONMENT SETUP COMPLETED SUCCESSFULLY!
# ...
