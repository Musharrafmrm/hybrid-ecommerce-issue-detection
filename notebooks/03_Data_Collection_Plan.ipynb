# %% [markdown]
# <a href="https://colab.research.google.com/github/Musharrafmrm/hybrid-ecommerce-issue-detection/blob/main/notebooks/03_Data_Collection_Plan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =============================================================================
# 03_Data_Collection_Plan.ipynb
# Hybrid Machine Learning for E-Commerce Review Issue Detection
# Student: M.R.M. Musharraf (20APC5036)
# =============================================================================

print("📥 DATASET COLLECTION\n")

print("Target: 150,000 – 180,000 cleaned reviews")
print("Sources: Public Kaggle datasets + Local Sri Lankan platforms\n")

# 1. Public Datasets (Kaggle)
print("1. PUBLIC DATASETS FROM KAGGLE (Download)")
print("• Amazon Product Reviews 2018 (Large & Reliable)")
print("  Link: https://www.kaggle.com/datasets/snap/amazon-fine-food-reviews")
print("• Flipkart Product Reviews Dataset")
print("  Link: https://www.kaggle.com/datasets/dhruvkothari/flipkart-products")
print("• Additional Multi-domain E-commerce Reviews")
print("  Link: https://www.kaggle.com/datasets/nicapotato/amazon-reviews (or search 'Amazon reviews 2018')")

print("\n2. LOCAL SRI LANKAN DATA (Ethical Scraping - Next Week)")
print("• Daraz.lk")
print("• Kapruka.com")
print("• Takas.lk")
print("Tools: BeautifulSoup / Scrapy (robots.txt compliant)")

print("\n3. Final Target Breakdown")
print("• Kaggle datasets     → ~120,000 reviews")
print("• Local scraping      → ~60,000 reviews")
print("• Total               → ~180,000 cleaned reviews")

print("\nNext Steps After Downloading:")
print("• Combine all CSV files")
print("• Remove duplicates and noise")
print("• Save as clean_dataset.csv in /data/ folder")

print("\n✅ Data Collection Plan Created.")
print("now ready to start actual downloading")
# Out:
# 📥 DATASET COLLECTION
#
# Target: 150,000 – 180,000 cleaned reviews
# Sources: Public Kaggle datasets + Local Sri Lankan platforms
#
# 1. PUBLIC DATASETS FROM KAGGLE (Download)
# • Amazon Product Reviews 2018 (Large & Reliable)
#   Link: https://www.kaggle.com/datasets/snap/amazon-fine-food-reviews
# • Flipkart Product Reviews Dataset
#   Link: https://www.kaggle.com/datasets/dhruvkothari/flipkart-products
# • Additional Multi-domain E-commerce Reviews
#   Link: https://www.kaggle.com/datasets/nicapotato/amazon-reviews (or search 'Amazon reviews 2018')
#
# 2. LOCAL SRI LANKAN DATA (Ethical Scraping - Next Week)
# • Daraz.lk
# • Kapruka.com
# • Takas.lk
# Tools: BeautifulSoup / Scrapy (robots.txt compliant)
#
# 3. Final Target Breakdown
# • Kaggle datasets     → ~120,000 reviews
# • Local scraping      → ~60,000 reviews
# • Total               → ~180,000 cleaned reviews
#
# Next Steps After Downloading:
# • Combine all CSV files
# • Remove duplicates and noise
# ...
