# %% [markdown]
# <a href="https://colab.research.google.com/github/Musharrafmrm/hybrid-ecommerce-issue-detection/blob/main/notebooks/02_Research_Summary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# =============================================================================
# # Hybrid Machine Learning for E-Commerce Review Issue Detection
# # Student: M.R.M. Musharraf (20APC5036)
# =============================================================================

# %%
print("📋 Research Summary - IS 8101 Project\n")

# Research Questions
print("RESEARCH QUESTIONS:")
print("RQ01: How can a hybrid model combining classical ML, deep learning, and unsupervised methods improve multi-class issue detection?")
print("RQ02: Which NLP preprocessing techniques are most effective for the hybrid model?")
print("RQ03: How does the model perform across different issue categories and what optimizations help?")
print("RQ04: Can the model handle noisy text, imbalanced data, and diverse platform reviews?")
print("RQ05: What actionable insights can the model provide to businesses?")

print("\nSPECIFIC OBJECTIVES:")
print("Objective 1: Develop hybrid model (SVM/RF + Bi-LSTM/BERT + LDA) → RQ01")
print("Objective 2: Find best NLP preprocessing techniques → RQ02")
print("Objective 3: Evaluate performance across issue categories → RQ03")
print("Objective 4: Test robustness on real-world data → RQ04")
print("Objective 5: Generate actionable business insights → RQ05")

print("\nEXPECTED OUTCOMES:")
print("Outcome 1: 90-95% accuracy in multi-class issue detection")
print("Outcome 2: Optimized NLP preprocessing framework")
print("Outcome 3: Consistent performance across all issue categories")
print("Outcome 4: Robust model for noisy & multilingual data")
print("Outcome 5: Clear business recommendations for e-commerce")

print("\nHYBRID MODEL ARCHITECTURE:")
print("1. Unsupervised Layer → LDA (Aspect Discovery)")
print("2. Deep Learning Layer → BERT / Bi-LSTM (Context understanding)")
print("3. Classical ML Layer → SVM + Random Forest (Final classification)")

print("\n✅ Research Summary Created.")
# Out:
# 📋 Research Summary - IS 8101 Project
#
# RESEARCH QUESTIONS:
# RQ01: How can a hybrid model combining classical ML, deep learning, and unsupervised methods improve multi-class issue detection?
# RQ02: Which NLP preprocessing techniques are most effective for the hybrid model?
# RQ03: How does the model perform across different issue categories and what optimizations help?
# RQ04: Can the model handle noisy text, imbalanced data, and diverse platform reviews?
# RQ05: What actionable insights can the model provide to businesses?
#
# SPECIFIC OBJECTIVES:
# Objective 1: Develop hybrid model (SVM/RF + Bi-LSTM/BERT + LDA) → RQ01
# Objective 2: Find best NLP preprocessing techniques → RQ02
# Objective 3: Evaluate performance across issue categories → RQ03
# Objective 4: Test robustness on real-world data → RQ04
# Objective 5: Generate actionable business insights → RQ05
#
# EXPECTED OUTCOMES:
# Outcome 1: 90-95% accuracy in multi-class issue detection
# ...
